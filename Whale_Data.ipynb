# %%
# Import Requests

import requests
import json
import time
import datetime

# %%
# Getting Response BTC API

response = requests.get('https://api.whale-alert.io/v1/transactions?api_key=zd1tXydtCfegKwzLvUIMPCAasDBMiCnk&currency=btc')
print(response)
# Out:
# <Response [200]>

# %%
# Print JSON

print(response.json())
# Out:
# {'result': 'success', 'cursor': '64563426-64562e60-612f4396', 'count': 100, 'transactions': [{'blockchain': 'bitcoin', 'symbol': 'btc', 'id': '1683364053', 'transaction_type': 'transfer', 'hash': 'Multiple Hashes', 'from': {'address': 'Multiple Addresses', 'owner_type': 'unknown'}, 'to': {'address': 'Multiple Addresses', 'owner_type': 'unknown'}, 'timestamp': 1630485720, 'amount': 10.890651, 'amount_usd': 516153.28, 'transaction_count': 1847}, {'blockchain': 'bitcoin', 'symbol': 'btc', 'id': '1683356915', 'transaction_type': 'transfer', 'hash': '61267ea4d5e3091340be978ed93df00302bf0379cceeebdbe19f223ececd2f6c', 'from': {'address': '18pJTT9CiyGzXYux6u28nHeDPUoC6pW6MG', 'owner': 'binance', 'owner_type': 'exchange'}, 'to': {'address': '1FhnvGSyy2YeLxSwHDJ9QkLL9T15kz92K5', 'owner': 'binance', 'owner_type': 'exchange'}, 'timestamp': 1630485743, 'amount': 26.134226, 'amount_usd': 1238609.8, 'transaction_count': 1}, {'blockchain': 'bitcoin', 'symbol': 'btc', 'id': '1683356916', 'transaction
# ...

# %%
# JSON JPRINT

def jprint(obj):
    text = json.dumps(obj, sort_keys=True, indent=3 )
    print(text)

jprint(response.json())
# Out:
# {
#    "count": 100,
#    "cursor": "644eb95c-644eae61-612dfef0",
#    "result": "success",
#    "transactions": [
#       {
#          "amount": 17.75912,
#          "amount_usd": 849477.44,
#          "blockchain": "bitcoin",
#          "from": {
#             "address": "Multiple Addresses",
#             "owner_type": "unknown"
#          },
#          "hash": "Multiple Hashes",
#          "id": "1682866141",
#          "symbol": "btc",
#          "timestamp": 1630401960,
#          "to": {
#             "address": "Multiple Addresses",
#             "owner_type": "unknown"
#          },
#          "transaction_count": 3151,
#          "transaction_type": "transfer"
#       },
#       {
#          "amount": 20.5916,
#          "amount_usd": 984964.25,
#          "blockchain": "bitcoin",
#          "from": {
#             "address": "Multiple Addresses",
#             "owner": "binance",
#             "owner_type": "exchange"
#          },
# ...

# %% [markdown]
# ####

# %%
timestamp = 1630404240
datetime = time.strftime('%A, %Y-%m-%d %H:%M:%S', time.localtime(timestamp))
print(datetime)
# Out:
# Tuesday, 2021-08-31 19:34:00
